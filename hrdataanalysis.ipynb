# %% [markdown]
# #### 1. Loading the Dataset

# %%
import pandas as pd

# Load the dataset
file_path =r"C:\Users\Shanu\Desktop\HR Data.csv"  
data = pd.read_csv(file_path)

# Display the first few rows
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/59.7 kB 1.4 MB/s eta 0:00:01
#      -------------------- ------------------- 30.7/59.7 kB 1.4 MB/s eta 0:00:01
#      -------------------------------- ----- 51.2/59.7 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 59.7/59.7 kB 287.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 1.9 MB/s eta 0:00:07
#    ---------------------------------------- 0.1/11.6 MB 975.2 kB/s eta 0:00:12
#    ---------------------------------------- 0.1/11.6 MB 1.0 MB/s eta 0:00:12
#     --------------------------------------- 0.2/11.6 MB 1.0 MB/s eta 0:00:12
#     --------------------------------------- 0.2/11.6 MB 803.1 kB/s eta 0:00:15
#     --------------------------------------- 0.2/11.6 MB 981.9 kB/s eta 0:00:12
# ...

# %%
# !pip install seaborn matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.9 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.9 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.9 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.9 kB 187.9 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/165.9 kB 187.9 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/165.9 kB 187.9 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/165.9 kB 182.2 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/165.9 kB 218.5 kB/s eta 0:00:01
#      -------------------- ---------------- 92.2/165.9 kB 218.5 kB/s eta 0:00:01
# ...

# %% [markdown]
# #### 2. Cleaning the Data
# #### Step 1: Removing unnecessary columns

# %%
# Drop unnecessary columns
data = data.drop(columns=['EmployeeCount', 'EmployeeNumber', 'StandardHours'])
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# #### Step 2:  Rename columns for clarity

# %%
data.rename(columns={
    'BusinessTravel': 'Travel_Frequency',
    'YearsAtCompany': 'Company_Tenure',
    'YearsInCurrentRole': 'CurrentRole_Years',
    'YearsSinceLastPromotion': 'Years_Since_Promotion',
    'YearsWithCurrManager': 'Manager_Tenure'
}, inplace=True)
data
# Out:
#       Age Attrition   Travel_Frequency  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# #### Step 3: Removing duplicate rows

# %%
# Remove duplicate rows
data.drop_duplicates(inplace=True)

# %% [markdown]
# #### Step 4: Handling missing values

# %%
# Drop rows with NaN values
data.dropna(inplace=True)

# %%
data
# Out:
#       Age Attrition   Travel_Frequency  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# #### 3. Exploratory Data Analysis

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
# Bar chart for Attrition Distribution
attrition_counts = data['Attrition'].value_counts()

plt.figure(figsize=(6,4))
attrition_counts.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Attrition Distribution')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.show()

# Pie chart for Department Distribution
plt.figure(figsize=(6,6))
data_cleaned['Department'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral'])
plt.title('Department Distribution')
plt.ylabel('')
plt.show()

# %%
# Convert categorical columns to numeric
data['Attrition'] = data['Attrition'].map({'Yes': 1, 'No': 0})

# Select only numeric columns for correlation matrix
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Correlation heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20,12))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### Key Insights from Correlation Map

# %% [markdown]
# ##### High Positive Correlations:
#
# MonthlyIncome and JobLevel: A correlation of 0.95 indicates a very strong positive relationship, suggesting that job level is a good predictor of salary, which is expected in organizational structures.
#
# TotalWorkingYears and JobLevel: A correlation of 0.78 demonstrates that more experienced employees typically hold higher job levels within the company.
#
# TotalWorkingYears and MonthlyIncome: Correlated at 0.77, indicating that employees with more years of total work experience tend to earn higher incomes.
#
# Company_Tenure and CurrentRole_Years: A correlation of 0.77 shows that employees who have been with the company longer also tend to have spent more time in their current roles.
#
# ##### Negative Correlations:
#
# Age and Attrition: Correlation value ~-0.16. There is a weak negative correlation, indicating that older employees tend to have lower attrition rates. This suggests that younger employees might be more likely to leave the company.
#
# MonthlyIncome and Attrition: Correlation value ~-0.16. This suggests that employees with higher monthly income are slightly less likely to leave the company, but the correlation is weak.
